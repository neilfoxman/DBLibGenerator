# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2


import numpy as np
from pint import UnitRegistry
ureg = UnitRegistry()
Q = ureg.Quantity

# %% [markdown]
# # Handling Common Values belonging to Specific E-Series

# %%
# Generate list of all possible significands and mappings to specific component value series
# https://eepower.com/resistor-guide/resistor-standards-and-codes/resistor-values/

def gen_significand3_map():
    """
    Different value series are stored with each significand in 3 digits or less.
    Generate a mapping from a 3-digit integer value to a value series.
    """

    # Value Series: "E6"
    E6_str = """
    10	15	22	33	47	68
    """

    # Value Series: "E12"...
    E12_str = """
    10	12	15	18	22	27
    33	39	47	56	68	82
    """

    E24_str = """
    10	11	12	13	15	16
    18	20	22	24	27	30
    33	36	39	43	47	51
    56	62	68	75	82	91
    """

    E48_str = """
    100	105	110	115	121	127
    133	140	147	154	162	169
    178	187	196	205	215	226
    237	249	261	274	287	301
    316	332	348	365	383	402
    422	442	464	487	511	536
    562	590	619	649	681	715
    750	787	825	866	909	953
    """

    E96_str = """
    100	102	105	107	110	113
    115	118	121	124	127	130
    133	137	140	143	147	150
    154	158	162	165	169	174
    178	182	187	191	196	200
    205	210	215	221	226	232
    237	243	249	255	261	267
    274	280	287	294	301	309
    316	324	332	340	348	357
    365	374	383	392	402	412
    422	432	442	453	464	475
    487	499	511	523	536	549
    562	576	590	604	619	634
    649	665	681	698	715	732
    750	768	787	806	825	845
    866	887	909	931	953	976
    """

    E192_str = """
    100	101	102	104	105	106	107	109	110	111	113	114
    115	117	118	120	121	123	124	126	127	129	130	132
    133	135	137	138	140	142	143	145	147	149	150	152
    154	156	158	160	162	164	165	167	169	172	174	176
    178	180	182	184	187	189	191	193	196	198	200	203
    205	208	210	213	215	218	221	223	226	229	232	234
    237	240	243	246	249	252	255	258	261	264	267	271
    274	277	280	284	287	291	294	298	301	305	309	312
    316	320	324	328	332	336	340	344	348	352	357	361
    365	370	374	379	383	388	392	397	402	407	412	417
    422	427	432	437	442	448	453	459	464	470	475	481
    487	493	499	505	511	517	523	530	536	542	549	556
    562	569	576	583	590	597	604	612	619	626	634	642
    649	657	665	673	681	690	698	706	715	723	732	741
    750	759	768	777	787	796	806	816	825	835	845	856
    866	876	887	898	909	920	931	942	953	965	976	988
    """

    

    def map_significand3_to_series(significand3_str, series, significand3_map):
        for significand3_str in significand3_str.split():
            significand3 = int(significand3_str.ljust(3, '0'))
            significand3_map[significand3] = series
        return significand3_map
    
    significand3_map = {}
    map_significand3_to_series(E192_str, 192, significand3_map)
    map_significand3_to_series(E96_str, 96, significand3_map)
    map_significand3_to_series(E48_str, 48, significand3_map)
    map_significand3_to_series(E24_str, 24, significand3_map)
    map_significand3_to_series(E12_str, 12, significand3_map)
    map_significand3_to_series(E6_str, 6, significand3_map)

    # Sort by key and return new dict
    return dict(sorted(significand3_map.items()))

significand3_map = gen_significand3_map()
print(significand3_map)
# Out:
        return SeriesValue(series=series, value=significand*pow(10, exponent))

    def __repr__(self):
        if isinstance(self.series, (int, float)):
            series = f'E{self.series}'
        else:
            series = self.series
        return f"series={series}: {self.value:.3}"


def gen_series_values_in_range(min_value, max_value, accepted_series_list, significand3_map):
    # Get scientific notation representation of min and max
    min_significand, min_expononent = val_to_scinot(min_value)
    max_significand, max_expononent = val_to_scinot(max_value)

    # Convert significand to 3 digit integer for easier comparison later (avoid comparing calculated floats for equality)
    min_significand3 = int(round(min_significand*100))
    max_significand3 = int(round(max_significand*100))

    # make a list of all SeriesValues between min and max
    series_value_list = []

    # For each exponent within min and max range
    for exponent in range(min_expononent, max_expononent+1):
        # Inspect each 3-digit significand of an acceptable component value series
        for significand3, series in significand3_map.items():
            print(significand3, series)
            if series in accepted_series_list:
                # If we are on the lowest or highest possible exponent, compare min and max significands too
                # Or if looking at an exponent between max and min exponent, then it automatically qualifies as a valid value
                if (exponent == min_expononent and significand3 >= min_significand3) or \
                (exponent == max_expononent and significand3 <= max_significand3) or \
                (exponent > min_expononent and exponent < max_expononent):
                    series_value_list.append(
                        SeriesValue.from_significand_exponent(
                            series=series,
                            significand=significand3/100.0,
                            exponent=exponent
                        )
                    )
    return series_value_list


gen_series_values_in_range(1, 10, accepted_series_list=[24, 96], significand3_map=significand3_map)
# Out:
# 100 6
# 101 192
# 102 96
# 104 192
# 105 48
# 106 192
# 107 96
# 109 192
# 110 24
# 111 192
# 113 96
# 114 192
# 115 48
# 117 192
# 118 96
# 120 12
# 121 48
# 123 192
# 124 96
# 126 192
# 127 48
# 129 192
# 130 24
# 132 192
# 133 48
# 135 192
# 137 96
# 138 192
# 140 48
# 142 192
# 143 96
# 145 192
# 147 48
# 149 192
# 150 6
# 152 192
# 154 48
# 156 192
# 158 96
# 160 24
# 162 48
# 164 192
# 165 96
# 167 192
# 169 48
# 172 192
# 174 96
# 176 192
# 178 48
# 180 12
# 182 96
# 184 192
# 187 48
# 189 192
# 191 96
# 193 192
# 196 48
# 198 192
# 200 24
# 203 192
# 205 48
# 208 192
# 210 96
# 213 192
# 215 48
# 218 192
# 220 6
# 221 96
# 223 192
# 226 48
# 229 192
# 232 96
# 234 192
# 237 48
# 240 24
# 243 96
# 246 192
# 249 48
# 252 192
# 255 96
# 258 192
# 261 48
# 264 192
# 267 96
# 270 12
# 271 192
# 274 48
# 277 192
# 280 96
# 284 192
# 287 48
# 291 192
# 294 96
# 298 192
# 300 24
# 301 48
# 305 192
# 309 96
# 312 192
# 316 48
# 320 192
# 324 96
# 328 192
# 330 6
# 332 48
# 336 192
# 340 96
# 344 192
# 348 48
# 352 192
# 357 96
# 360 24
# 361 192
# 365 48
# 370 192
# 374 96
# 379 192
# 383 48
# 388 192
# 390 12
# 392 96
# 397 192
# 402 48
# 407 192
# 412 96
# 417 192
# 422 48
# 427 192
# 642 192
# 649 48
# 657 192
# 665 96
# 673 192
# 680 6
# 681 48
# 690 192
# 698 96
# 706 192
# 715 48
# 723 192
# 732 96
# 741 192
# 750 24
# 759 192
# 768 96
# 777 192
# 787 48
# 796 192
# 806 96
# 816 192
# 820 12
# 825 48
# 835 192
# 845 96
# 856 192
# 866 48
# 876 192
# 887 96
# 898 192
# 909 48
# 910 24
# 920 192
# 931 96
# 942 192
# 953 48
# 965 192
# 976 96
# 988 192
# [series=E96: 1.02,
#  series=E96: 1.07,
#  series=E24: 1.1,
#  series=E96: 1.13,
#  series=E96: 1.18,
#  series=E96: 1.24,
#  series=E24: 1.3,
#  series=E96: 1.37,
#  series=E96: 1.43,
#  series=E96: 1.58,
#  series=E24: 1.6,
#  series=E96: 1.65,
#  series=E96: 1.74,
#  series=E96: 1.82,
#  series=E96: 1.91,
#  series=E24: 2.0,
#  series=E96: 2.1,
#  series=E96: 2.21,
#  series=E96: 2.32,
#  series=E24: 2.4,
#  series=E96: 2.43,
#  series=E96: 2.55,
#  series=E96: 2.67,
#  series=E96: 2.8,
#  series=E96: 2.94,
#  series=E24: 3.0,
#  series=E96: 3.09,
#  series=E96: 3.24,
#  series=E96: 3.4,
#  series=E96: 3.57,
#  series=E24: 3.6,
#  series=E96: 3.74,
#  series=E96: 3.92,
#  series=E96: 4.12,
#  series=E24: 4.3,
#  series=E96: 4.32,
#  series=E96: 4.53,
#  series=E96: 4.75,
#  series=E96: 4.99,
#  series=E24: 5.1,
#  series=E96: 5.23,
#  series=E96: 5.49,
#  series=E96: 5.76,
#  series=E96: 6.04,
#  series=E24: 6.2,
#  series=E96: 6.34,
#  series=E96: 6.65,
#  series=E96: 6.98,
#  series=E96: 7.32,
#  series=E24: 7.5,
#  series=E96: 7.68,
#  series=E96: 8.06,
#  series=E96: 8.45,
#  series=E96: 8.87,
#  series=E24: 9.1,
#  series=E96: 9.31,
#  series=E96: 9.76]

# %% [markdown]
# # Generic Component Classes with Parameters to Match DBLib

# %%
# Generate base class for component in database to help enforce parameters needed
class ComponentBase:
    def __init__(
        self,
        description,
        comment,
        manufacturer,
        manufacturer_pn,
        symbol_path,
        symbol_ref,
        footprint_path,
        footprint_ref,
        *args,
        **kwargs):

        self.description = description
        self.comment = comment
        self.manufacturer = manufacturer
        self.manufacturer_pn = manufacturer_pn
        self.symbol_path = symbol_path
        self.symbol_ref = symbol_ref
        self.footprint_path = footprint_path
        self.footprint_ref = footprint_ref
        for arg in args:
            print(f"Warning: Unassigned argument: {arg}")
        for key, val in kwargs.items():
            print(f"Warning: Unassigned key-val pair: {key} : {val}")

    def to_dict(self):
        # https://www.altium.com/documentation/altium-designer/creating-defining-database-library
        d = {}
        d['Description'] = self.description
        d['Comment'] = self.comment
        d['Manufacturer'] = self.manufacturer
        d['Manufacturer Part Number'] = self.manufacturer_pn
        d['Library Path'] = self.symbol_path
        d['Library Ref'] = self.symbol_ref
        d['Footprint Path'] = self.footprint_path
        d['Footprint Ref'] = self.footprint_ref
        return d

class ValuedComponent(ComponentBase):
    def __init__(
        self,
        value,
        series,
        tolerance,
        *args,
        **kwargs):

        super().__init__(*args, **kwargs)
        self.value = value
        self.series = series
        self.tolerance = tolerance
    
    def to_dict(self):
        d = super().to_dict()
        d['Value'] = self.value
        d['Series'] = self.series
        d['Tolerance'] = self.tolerance
        return d

class ChipComponent(ValuedComponent):
    def __init__(
        self,
        size,
        power_rating,
        *args,
        **kwargs):

        super().__init__(*args, **kwargs)
        self.size = size
        self.power_rating = power_rating
    
    def to_dict(self):
        d = super().to_dict()
        d['Package / Case'] = self.size
        d['Power Rating'] = self.power_rating
        return d

# R = ValuedComponent(
R = ChipComponent(
    value='5R',
    series='Esomething',
    tolerance='1%',
    size='0804',
    power_rating='1/8W',
    description='dscrpt',
    comment='comment',
    manufacturer='mfg',
    manufacturer_pn='pn',
    symbol_path='sympath',
    symbol_ref='symref',
    footprint_path='footpath',
    footprint_ref='footref'
)
R.to_dict()
# Out:
# {'Description': 'dscrpt',
#  'Comment': 'comment',
#  'Manufacturer': 'mfg',
#  'Manufacturer Part Number': 'pn',
#  'Library Path': 'sympath',
#  'Library Ref': 'symref',
#  'Footprint Path': 'footpath',
#  'Footprint Ref': 'footref',
#  'Value': '5R',
#  'Series': 'Esomething',
#  'Tolerance': '1%',
#  'Package / Case': '0804',
#  'Power Rating': '1/8W'}

# %% [markdown]
# # Yageo RC_L Series

# %%
SYMBOL_PATH = 'PassiveSymbols.SchLib'
FOOTPRINT_PATH = 'PassiveFootprints.PcbLib'



class Yageo_RC_L:
    sizes = [
        '0075',
        '0100',
        '0201',
        '0402',
        '0603',
        '0805',
        '1206',
        '1210',
        '1218',
        '2010',
        '2512'
    ]
    tolerance_labels = {
        '0.1%' : 'B',
        '0.5%' : 'D',
        '1.0%' : 'F',
        '5.0%' : 'J' # Also for jumpers
    }

    packaging_labels = {
        'Paper taping reel': 'R',
        'Embossed taping reel': 'K',
        'ESD safe reel (0075/0100 only)': 'S'
    }

    reel_power_labels = {
        '7 inch dia. Reel & Standard power': '07',
        '10 inch dia. Reel': '10',
        '13 inch dia. Reel': '13',
        '7 inch dia. Reel & 2 x standard power': '7W',
        '7 inch dia. Reel, ESD safe reel (0075/0100 only)': '7N',
        '13 inch dia. Reel & 2 x standard power': '3W'
    }

    def gen_resistance_str(resistance):
        significand, exponent = val_to_scinot(resistance)
        significand3_str = str(round(significand*100))
        
        # Determine resistance string
        if exponent < 3:
            return f"{significand3_str[:exponent+1]}R{significand3_str[exponent+1:].rstrip('0')}"
        elif exponent < 6:
            return f"{significand3_str[:exponent-2]}K{significand3_str[exponent-2:].rstrip('0')}"
        elif exponent < 9:
            return f"{significand3_str[:exponent-5]}M{significand3_str[exponent-5:].rstrip('0')}"
        
    def gen_pn(size, tolerance, packaging, reel_power, resistance):
        tolerance_label = Yageo_RC_L.tolerance_labels[tolerance]
        packaging_label = Yageo_RC_L.packaging_labels[packaging]
        reel_power_label = Yageo_RC_L.reel_power_labels[reel_power]
        resistance_label = Yageo_RC_L.gen_resistance_str(resistance)
        return f'RC{size}{tolerance_label}{packaging_label}-{reel_power_label}{resistance_label}L'

    def gen_components():
        component_list = []

        # Using some common parameters across all components for now
        packaging = 'Paper taping reel'
        reel_power = '7 inch dia. Reel & Standard power'

        # Size we are generating for
        size = '0805'

        # Add jumper to list first (not in series maps)
        resistance = 0
        component_list.append(
            ChipComponent(
                value=Yageo_RC_L.gen_resistance_str(resistance),
                series='Jumper',
                tolerance='Jumper',
                size=size,
                power_rating='Jumper',
                description=f'{Yageo_RC_L.gen_resistance_str(resistance)} Jumper, {size}',
                comment='=Value',
                manufacturer='Yageo',
                manufacturer_pn=Yageo_RC_L.gen_pn(
                    size=size,
                    tolerance='5.0%', # Used for jumpers according to datasheet
                    packaging=packaging,
                    reel_power=reel_power,
                    resistance=0,
                ),
                symbol_path=SYMBOL_PATH,
                symbol_ref='Resistor',
                footprint_path=FOOTPRINT_PATH,
                footprint_ref=size,
            ).to_dict()
        )

        # Now generate all resistors
        power_rating = '1/8W'
        # series_values = gen_series_values_in_range(min_value=1, max_value=10e6, accepted_series_list=[24, 96], significand3_map=significand3_map)
        series_values = gen_series_values_in_range(min_value=1, max_value=10, accepted_series_list=[24, 96], significand3_map=significand3_map)
        print(f"series_values[0]={series_values[0]}")
        tolerances = ['1.0%']
        for tolerance in tolerances:
            for series_value in series_values:
                component_list.append(
                    ChipComponent(
                        value=Yageo_RC_L.gen_resistance_str(series_value.value),
                        series=series_value.series,
                        tolerance=tolerance,
                        size=size,
                        power_rating=power_rating,
                        description=f'{Yageo_RC_L.gen_resistance_str(series_value.value)} {tolerance} Resistor, {size}, {power_rating}',
                        comment='=Value',
                        manufacturer='Yageo',
                        manufacturer_pn=Yageo_RC_L.gen_pn(
                            size=size,
                            tolerance=tolerance,
                            packaging=packaging,
                            reel_power=reel_power,
                            resistance=series_value.value,
                        ),
                        symbol_path=SYMBOL_PATH,
                        symbol_ref='Resistor',
                        footprint_path=FOOTPRINT_PATH,
                        footprint_ref=size,
                    ).to_dict()
                )


        return component_list
    

# Yageo_RC_L.gen_pn(
#     size='0805',
#     tolerance='1.0%',
#     packaging='Paper taping reel',
#     reel_power='7 inch dia. Reel & Standard power',
#     resistance=10e6
# )
Yageo_RC_L.gen_components()
# Out:
# series_values[0]=series=E96: 1.02
# [{'Description': '0R Jumper, 0805',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805JR-070RL',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '0R',
#   'Series': 'Jumper',
#   'Tolerance': 'Jumper',
#   'Package / Case': '0805',
#   'Power Rating': 'Jumper'},
#  {'Description': '1R02 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R02L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R02',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R07 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R07L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R07',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R1 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R1L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R1',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R13 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R13L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R13',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R18 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R18L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R18',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R24 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R24L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R24',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R3 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R3L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R3',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R37 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R37L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R37',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R43 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R43L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R43',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R58 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R58L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R58',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R6 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R6L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R6',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R65 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R65L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R65',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R74 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R74L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R74',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R82 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R82L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R82',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '1R91 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-071R91L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '1R91',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072RL',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R1 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R1L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R1',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R21 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R21L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R21',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R32 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R32L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R32',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R4 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R4L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R4',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R43 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R43L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R43',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R55 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R55L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R55',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R67 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R67L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R67',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R8 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R8L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R8',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '2R94 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-072R94L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '2R94',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073RL',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R09 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R09L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R09',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R24 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R24L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R24',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R4 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R4L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R4',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R57 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R57L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R57',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R6 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R6L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R6',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R74 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R74L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R74',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '3R92 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-073R92L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '3R92',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R12 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R12L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R12',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R3 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R3L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R3',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R32 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R32L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R32',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R53 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R53L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R53',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R75 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R75L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R75',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '4R99 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-074R99L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '4R99',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '5R1 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-075R1L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '5R1',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '5R23 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-075R23L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '5R23',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '5R49 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-075R49L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '5R49',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '5R76 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-075R76L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '5R76',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '6R04 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-076R04L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '6R04',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '6R2 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-076R2L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '6R2',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '6R34 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-076R34L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '6R34',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '6R65 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-076R65L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '6R65',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '6R98 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-076R98L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '6R98',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '7R32 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-077R32L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '7R32',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '7R5 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-077R5L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '7R5',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '7R68 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-077R68L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '7R68',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '8R06 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-078R06L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '8R06',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '8R45 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-078R45L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '8R45',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '8R87 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-078R87L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '8R87',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '9R1 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-079R1L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '9R1',
#   'Series': 24,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '9R31 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-079R31L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '9R31',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'},
#  {'Description': '9R76 1.0% Resistor, 0805, 1/8W',
#   'Comment': '=Value',
#   'Manufacturer': 'Yageo',
#   'Manufacturer Part Number': 'RC0805FR-079R76L',
#   'Library Path': 'PassiveSymbols.SchLib',
#   'Library Ref': 'Resistor',
#   'Footprint Path': 'PassiveFootprints.PcbLib',
#   'Footprint Ref': '0805',
#   'Value': '9R76',
#   'Series': 96,
#   'Tolerance': '1.0%',
#   'Package / Case': '0805',
#   'Power Rating': '1/8W'}]

# %%
        

        

    


        
        
        
        

        # d = {}
        # d['Package / Case'] = size
        # if resistance_str == '0R':
        #     d['Tolerance'] = 'Jumper'
        # else:
        #     d['Tolerance'] = Yageo_RC_L.tolerances[tolerance]
        # d['Packaging'] = Yageo_RC_L.packagings[packaging]

        # power_factor = 1
        # if 'W' in reel_power:
        #     power_factor = 2

        # if size == '0075':
        #     d['Power Rating'] = '1/50W'
        # elif size == '0100':
        #     d['Power Rating'] = '1/32W'
        # elif size == '0201':
        #     d['Power Rating'] = '1/20W'
        # elif size == '0402':
        #     if 'W' not in reel_power:
        #         d['Power Rating'] = '1/16W'
        #     else:
        #         d['Power Rating'] = '1/8W'
        # elif size == '0603':
        #     if 'W' not in reel_power:
        #         d['Power Rating'] = '1/10W'
        #     else:
        #         d['Power Rating'] = '1/5W'
        # elif size == '0805':
        #     if 'W' not in reel_power:
        #         d['Power Rating'] = '1/8W'
        #     else:
        #         d['Power Rating'] = '1/4W'
        # elif size == '1206':
        #     if 'W' not in reel_power:
        #         d['Power Rating'] = '1/4W'
        #     else:
        #         d['Power Rating'] = '1/2W'
        # elif size == '1210':
        #     d['Power Rating'] = '1/2W'
        # elif size == '1218':
        #     d['Power Rating'] = '1W'
        # elif size == '2010':
        #     d['Power Rating'] = '3/4W'
        # elif size == '2512':
        #     if 'W' not in reel_power:
        #         d['Power Rating'] = '1W'
        #     else:
        #         d['Power Rating'] = '2W'
        # else:
        #     d['Power Rating'] = ''
        # if resistance_str == '0R':
        #     d['Power Rating'] = 'Jumper'

        # d['Value'] = resistance_str
        # return d
# Out:
#   Cell In[16], line 91
#     gen_series_values_in_range(min_value=1, max_value=10e6, accepted_series_list, significand3_map)
#                                                                                                   ^
# SyntaxError: positional argument follows keyword argument

# %%
size = '0805'
tolerance = 'F'
packaging = 'R'
reel_power = '07'

# Generate list of resistance strings
resistances = [
    {''}
]
for exponent in range(0, 9):
    for significand_3 in all_resistances:    
        # Determine resistance string
        resistance_str = ''
        if exponent < 3:
            resistances.append(significand_3[:exponent+1] + 'R' + significand_3[exponent+1:].rstrip('0'))
        elif exponent < 6:
            resistances.append(significand_3[:exponent-2] + 'K' + significand_3[exponent-2:].rstrip('0'))
        elif exponent < 9:
            resistances.append(significand_3[:exponent-2] + 'M' + significand_3[exponent-2:].rstrip('0'))
# print(resistances)

for resistance in resistances:
    # Generate component propoerties
    d = Yageo_RC_L.gen_properties(size, tolerance, packaging, reel_power, resistance)

    # Determine base series and add as parameter
    significand_3 = resistance
    significand_3 = significand_3.replace('R','')
    significand_3 = significand_3.replace('K','')
    significand_3 = significand_3.replace('M','')
    significand_3 = significand_3.ljust(3, '0')
    if significand_3 == '0':
        value_series = 'Jumper'
    elif significand_3 in E6:
        value_series = 'E6'
    elif significand_3 in E12:
        value_series = 'E12'
    elif significand_3 in E24:
        value_series = 'E24'
    elif significand_3 in E48:
        value_series = 'E48'
    else:
        value_series = 'E96'   
    d['Value Series'] = value_series

    d['Library Path'] = 'Symbols.SchLib'
    d['Library Ref'] = 'Resistor'
    d['Footprint Path'] = 'Footprints.PcbLib'
    d['Footprint Ref'] = size
    
    print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       7 resistances = [
#       8     {''}
#       9 ]
#      10 for exponent in range(0, 9):
# ---> 11     for significand_3 in all_resistances:
#      12         # Determine resistance string
#      13         resistance_str = ''
#      14         if exponent < 3:
#
# NameError: name 'all_resistances' is not defined

# %%
'a'.ljust(3, '0')
# Out:
# 'a00'
